# %% [markdown]
# # Домашнє завдання: Візуалізація даних з matplotlib
#
# У цьому завданні потрібно:
# 1. Побудувати 3 математичні функції на одному графіку.
# 2. Створити секторну діаграму.
# 3. Створити комбіновану візуалізацію subplots (2x2).
# 4. Додати інтерактивні елементи (віджети).
# 5. Додати анімований графік.
# 6. Зберегти графік у PNG.
